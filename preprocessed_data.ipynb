# %%
# Import Libraries & Upload Dataset
import pandas as pd
from sklearn.preprocessing import StandardScaler
df=pd.read_csv("heart_disease.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PATIENT_ID  10000 non-null  int64
#  1   AGE         10000 non-null  int64
#  2   GENDER      10000 non-null  object
#  3   Heart_rate  10000 non-null  int64
#  4   BP          9481 non-null   float64
#  5   Cholestrol  9452 non-null   float64
#  6   ECG         10000 non-null  int64
#  7   Chest pain  10000 non-null  int64
#  8   Target      10000 non-null  int64
#  9   Unnamed: 9  0 non-null      float64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 781.4+ KB
# None

# %%
#Check Missing Values:
print(df.isnull().sum())
# Out:
# PATIENT_ID        0
# AGE               0
# GENDER            0
# Heart_rate        0
# BP              519
# Cholestrol      548
# ECG               0
# Chest pain        0
# Target            0
# Unnamed: 9    10000
# dtype: int64

# %%
# Remove Unwanted COlumns:
df.drop(columns=['Unnamed: 9'],inplace=True)
df.drop(columns=['PATIENT_ID'],inplace=True)

# %%
#Remove Null Values:
df.dropna(inplace=True)

# %%
# Convert Categorical Data
if 'GENDER' in df.columns:
    df['GENDER']=df['GENDER'].map({'M':1,'F':0})

# %%
# Feature Selection:
x=df.drop("Target",axis=1)
y=df["Target"]

# %%
# Feature Scaling:
scaler=StandardScaler()
columns=x.columns
x_scaled=scaler.fit_transform(x)

# %%
# Convert Back To Dataframe:
x=pd.DataFrame(x_scaled,columns=columns)

# %%
print(x.head())
print(y.head())
# Out:
#         AGE    GENDER  Heart_rate        BP  Cholestrol       ECG  Chest pain
# 0 -1.704702  0.988891   -1.141660  0.907311   -0.987286  1.244638   -0.450241
# 1 -0.279873 -1.011234   -0.339546  1.362719   -1.691135 -1.215236    1.343110
# 2  1.501164  0.988891   -0.998426 -0.345062    1.192926 -1.215236   -0.450241
# 3 -1.348495  0.988891    1.579800  1.362719    1.141425  0.014701    0.446435
# 4 -0.849804 -1.011234   -0.396840  0.262149   -1.073121  1.244638   -1.346916
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Target, dtype: int64

# %%
# Save Cleaned Dataset
cleaned_df=pd.concat([x,y],axis=1)
cleaned_df.to_csv("cleaned_heart_data.csv",index=False)

# %%
print("PHASE 1 COMPLETED SUCCESSFULLY...")
# Out:
# PHASE 1 COMPLETED SUCCESSFULLY...
